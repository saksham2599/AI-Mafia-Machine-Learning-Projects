# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
my_data = pd.read_csv('./Training_Data/Train.csv')
my_test_data = pd.read_csv('./Testing_Data/Test.csv')

# %%
my_data.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5     target
# 0   0.293416  -0.945599  -0.421105   0.406816   0.525662 -82.154667
# 1  -0.836084  -0.189228  -0.776403  -1.053831   0.597997 -48.897960
# 2   0.236425   0.132836  -0.147723   0.699854  -0.187364  77.270371
# 3   0.175312   0.143194  -0.581111  -0.122107  -1.292168  -2.988581
# 4  -1.693011   0.542712  -2.798729  -0.686723   1.244077 -37.596722

# %% [markdown]
# # Normalize the data:

# %%
my_data = (my_data - my_data.mean())/my_data.std()
my_data.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5    target
# 0   0.290074  -0.898431  -0.372265   0.441633   0.524860 -0.744738
# 1  -0.842441  -0.158180  -0.723430  -0.994331   0.598773 -0.444429
# 2   0.232931   0.157021  -0.102063   0.729718  -0.203718  0.694875
# 3   0.171655   0.167158  -0.530410  -0.078352  -1.332620 -0.029866
# 4  -1.701656   0.558161  -2.722236  -0.633427   1.258945 -0.342379

# %% [markdown]
# # Create Matrices and Set Hyperparameters:

# %%
X = my_data.iloc[:, 0:5]
ones = np.ones([X.shape[0], 1])
X = np.concatenate((ones, X), axis = 1)

y = my_data.iloc[:, 5:6].values
theta = np.zeros([1,3])

#set hyperparameters
alpha = 0.01
iters = 1000

# %% [markdown]
# # Create the Cost Function

# %%
def computeCost(X, y, theta):
    tobesummed = np.power(((X @ theta.T)-y),2)
    return np.sum(tobesummed)/(2*len(X))

# %% [markdown]
# # Create the Gradient Descent Function:

# %%
#gradient descent
def gradientDescent(X,y,theta,iters,alpha):
    cost = np.zeros(iters)
    for i in range(iters):
        theta = theta - (alpha/len(X)) * np.sum(X * (X @ theta.T - y), axis=0)
        cost[i] = computeCost(X, y, theta)
    
    return theta,cost

#running the gd and cost function
g,cost = gradientDescent(X,y,theta,iters,alpha)
print(g)

finalCost = computeCost(X,y,g)
print(finalCost)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-849aaf00b747> in <module>
#       9
#      10 #running the gd and cost function
# ---> 11 g,cost = gradientDescent(X,y,theta,iters,alpha)
#      12 print(g)
#      13
#
# <ipython-input-12-849aaf00b747> in gradientDescent(X, y, theta, iters, alpha)
#       3     cost = np.zeros(iters)
#       4     for i in range(iters):
# ----> 5         theta = theta - (alpha/len(X)) * np.sum(X * (X @ theta.T - y), axis=0)
#       6         cost[i] = computeCost(X, y, theta)
#       7
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 6)

# %%
#plot the cost
fig, ax = plt.subplots()  
ax.plot(np.arange(iters), cost, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Training Epoch')
